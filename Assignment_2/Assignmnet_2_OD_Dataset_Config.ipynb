# %% [markdown]
# ### 42028 : Deep Learning and CNN
# ### Assignment 2
#
# | Name | Swapnil Ajit Chhatre |
# | :--- | :--- |
# | Student ID | 25675238 |
# | Tutorial | 04 (Wednesday 12.00 - 15.00) |
# | Tutor | Mr. Deep Patel |
#
# This notebook contains dataset configurations for running the Object Detection task on ClearML

# %%
from clearml import Dataset

# Creating a new dataset container for ClearML
dataset = Dataset.create(
    dataset_name="FastRCNN_ObjectDetection_Data", 
    dataset_project="Assignment 2 : Object Detection"
)

dataset.add_files(path="./25675238/Object_Detection")

# Uploading data to ClearML
dataset.upload()
dataset.finalize()
# Out:
# ClearML results page: https://app.clear.ml/projects/b0c60a28bbf34b079632d0df7ed7bc5b/experiments/39dfa6c3d89f43d19f7c0b293be1ca28/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/b0c60a28bbf34b079632d0df7ed7bc5b/experiments/39dfa6c3d89f43d19f7c0b293be1ca28
# Generating SHA2 hash for 7562 files
# ...
# 100%|██████████| 7562/7562 [00:08<00:00, 868.93it/s]
# Hash generation completed
# Uploading dataset changes (1921 files compressed to 289.81 MiB) to https://files.clear.ml
#                                           0% | 0.00/289.81 MB [00:00<?, ?MB/s]:
# █                                3% | 10.00/289.81 MB [00:00<00:12, 22.27MB/s]:
# █▌                               5% | 15.00/289.81 MB [00:01<00:20, 13.44MB/s]:
# ██                               7% | 20.00/289.81 MB [00:01<00:21, 12.84MB/s]:
# ██▌                              9% | 25.00/289.81 MB [00:01<00:21, 12.51MB/s]:
# ███                             10% | 30.00/289.81 MB [00:02<00:21, 12.32MB/s]:
# ...
